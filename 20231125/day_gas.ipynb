# %%
import matplotlib.pyplot as plt
from matplotlib.figure import FigureBase
import pandas as pd
import numpy as np


data = pd.read_csv(r"\\wsl.localhost\Ubuntu\home\wcz\github\iTransformer\dataset\GAS\1104.csv",header=None)

# 提取每天每半小时的用气量作为特征
# X = df['gas_usage']
X = data[0].to_numpy().reshape((-1,48))
print(X.shape)
# Out:
# (539, 48)

# %%
day_gas = np.sum(X,axis=1)
print(day_gas.shape)
# Out:
# (539,)

# %%
plt.plot(day_gas[:56])

# %%
import torch
torch.cuda.is_available()
# Out:
# True
